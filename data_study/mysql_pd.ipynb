# %%
import pandas as pd
import pymysql

conn = pymysql.connect(
    host='horusa',
    port=3306,
    user='root',
    password='root',
    db='horus'
)

query = """SELECT * FROM crawl_unit1 
where REG_DATE < '2025-06-21' and REG_DATE >= '2025-06-20'
ORDER BY CRAWL_NO DESC LIMIT 100
"""
sql_data = pd.read_sql_query(query, conn)
conn.close()

sql_data
# Out:
# /var/folders/bt/gmxyk66s42x8lzznw58fqs5w0000gn/T/ipykernel_58405/208895825.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_data = pd.read_sql_query(query, conn)
#     CRAWL_NO                                                URL  \
# 0   17322505  https://www.ppomppu.co.kr/zboard/view.php?id=f...
# 1   17322504  https://n.news.naver.com/mnews/article/003/001...
# 2   17322503  https://www.ppomppu.co.kr/zboard/view.php?id=f...
# 3   17322502  https://www.ppomppu.co.kr/zboard/view.php?id=f...
# 4   17322501  https://www.ppomppu.co.kr/zboard/view.php?id=f...
# ..       ...                                                ...
# 95  17322410  https://n.news.naver.com/mnews/article/077/000...
# 96  17322409  https://n.news.naver.com/mnews/article/077/000...
# 97  17322408  https://n.news.naver.com/mnews/article/056/001...
# ...
